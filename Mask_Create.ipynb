# %%
import cv2
import numpy as np
# from google.colab.patches import cv2_imshow  # Import cv2_imshow for Colab

# Define court rectangle
min_x, min_y = 100,10    # Example top-left corner of the court in pixels
max_x, max_y = 500,100   # Example bottom-right corner in pixels
court_color = (0, 255, 0)  # Green rectangle for court boundaries

# Load the video
cap = cv2.VideoCapture('final.mp4')

# Simple background subtraction for tracking
fgbg = cv2.createBackgroundSubtractorMOG2(history=200, varThreshold=70, detectShadows=False)
flag= False
# Initialize video writer to save the output
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('shuttlecock_tracking.mp4', fourcc, cap.get(cv2.CAP_PROP_FPS),
                      (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))
mask_out = cv2.VideoWriter('shuttlecock_mask_tracking.mp4', fourcc, cap.get(cv2.CAP_PROP_FPS),
                      (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))),isColor = False)
while cap.isOpened():
    flag = False
    ret, frame = cap.read()
    if not ret:
        break

    # Draw court boundaries
    cv2.rectangle(frame, (min_x,min_y), (max_x,max_y), (255,255,255), 2)
    # Apply background subtraction
    blurred_frame = cv2.GaussianBlur(frame, (7, 7), 0)
    gray_frame = cv2.cvtColor(blurred_frame, cv2.COLOR_BGR2GRAY)
    fgmask = fgbg.apply(gray_frame[min_y:max_y,min_x:max_x])
    # Find contours for potential shuttlecock positions
    fgmask[fgmask == 127] = 0
    _, fgmask = cv2.threshold(fgmask, 100,255,cv2.THRESH_BINARY)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    fgmask = cv2.morphologyEx(fgmask, cv2.MORPH_OPEN, kernel)
    # contours, _ = cv2.findContours(fgmask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours, _ = cv2.findContours(fgmask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    for cnt in contours:
        # Filter out small noise
        if cv2.contourArea(cnt)> 10:
            x, y, w, h = cv2.boundingRect(cnt)
            print("x = ",x,'\n','y = ',y)
            center = (x + w // 2, y + h // 2)
            # print('x',min_x,x,max_x,'\n','y',min_y,y,max_y)
            if (0 < x and 620 > x) and (0 < y and 99 > y):
                print("x = ",x,'\n','y = ',y)
                # print("In Bound")
                cv2.putText(frame, "In Bound", ((min_x+max_x)//2,(min_y+max_y)//2), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,255,0), 2)
                cv2.rectangle(frame, (min_x,min_y), (max_x,max_y), (0,255,0), 2)
                flag = True
    if flag:
        out.write(frame)
        
        continue
                # cv2.putText(fgmask, "In Bound", ((min_x+max_x)//2,(min_y+max_y)//2), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2)
                # cv2.rectangle(fgmask, (min_x,min_y), (max_x,max_y), (255,255,255), 2)
        # if cv2.contourArea(cnt) < 10:
    
    cv2.putText(frame, "Out of Bound", ((min_x+max_x)//2,(min_y+max_y)//2), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 2)
    cv2.rectangle(frame, (min_x,min_y), (max_x,max_y), (0,0,255), 2)
                # cv2.putText(fgmask, "Out of Bound", ((min_x+max_x)//2,(min_y+max_y)//2), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2)
                # cv2.rectangle(fgmask, (min_x,min_y), (max_x,max_y), (255,255,255), 2)
    print('-------------------------------------------------')
    # Save the frame to the output video
    
    out.write(frame)
    # mask_out.write(fgmask)
    # Display the frame inline in Colab

cap.release()
out.release()
# mask_out.release()
print("Processed video saved as 'shuttlecock_tracking.mp4'.")
# Out:
# x =  0
#  y =  0
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# x =  183
#  y =  82
# x =  183
#  y =  82
# x =  183
#  y =  82
# x =  183
#  y =  82
# x =  192
#  y =  70
# x =  192
#  y =  70
# x =  201
#  y =  61
# x =  201
#  y =  61
# x =  208
#  y =  53
# x =  208
#  y =  53
# x =  215
#  y =  47
# x =  215
#  y =  47
# x =  222
#  y =  42
# x =  222
#  y =  42
# x =  222
#  y =  42
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# x =  275
#  y =  0
# -------------------------------------------------
# x =  277
#  y =  5
# x =  277
#  y =  5
# x =  279
#  y =  13
# x =  279
#  y =  13
# x =  281
#  y =  22
# x =  281
#  y =  22
# x =  284
#  y =  32
# x =  284
#  y =  32
# x =  284
#  y =  32
# x =  284
#  y =  32
# x =  285
#  y =  42
# x =  285
#  y =  42
# x =  287
#  y =  54
# x =  287
#  y =  54
# x =  288
#  y =  65
# x =  288
#  y =  65
# x =  289
#  y =  77
# x =  289
#  y =  77
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# x =  217
#  y =  85
# x =  217
#  y =  85
# x =  223
#  y =  82
# x =  223
#  y =  82
# x =  223
#  y =  82
# x =  223
#  y =  82
# x =  230
#  y =  79
# x =  230
#  y =  79
# x =  237
#  y =  77
# x =  237
#  y =  77
# x =  243
#  y =  77
# x =  243
#  y =  77
# x =  249
#  y =  77
# x =  249
#  y =  77
# x =  255
#  y =  78
# x =  255
#  y =  78
# x =  255
#  y =  78
# x =  255
#  y =  78
# x =  261
#  y =  80
# x =  261
#  y =  80
# x =  266
#  y =  83
# x =  266
#  y =  83
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# -------------------------------------------------
# x =  311
#  y =  76
# x =  311
#  y =  76
# x =  309
#  y =  57
# x =  309
#  y =  57
# x =  308
#  y =  45
# x =  308
#  y =  45
# x =  308
#  y =  33
# x =  308
#  y =  33
# x =  308
#  y =  33
# x =  308
#  y =  33
# x =  307
#  y =  24
# x =  307
#  y =  24
# x =  306
#  y =  17
# x =  306
#  y =  17
# x =  306
#  y =  13
# x =  306
#  y =  13
# x =  305
#  y =  8
# x =  305
#  y =  8
# x =  305
#  y =  6
# x =  305
#  y =  6
# x =  305
#  y =  6
# x =  305
#  y =  6
# x =  304
#  y =  4
# x =  304
#  y =  4
# x =  304
#  y =  3
# x =  304
#  y =  3
# x =  303
#  y =  3
# x =  303
#  y =  3
# x =  303
#  y =  4
# x =  303
#  y =  4
# x =  302
#  y =  6
# x =  302
#  y =  6
# x =  302
#  y =  6
# x =  302
#  y =  6
# x =  302
#  y =  8
# x =  302
#  y =  8
# x =  301
#  y =  10
# x =  301
#  y =  10
# x =  301
#  y =  14
# x =  301
#  y =  14
# x =  301
#  y =  18
# x =  301
#  y =  18
# x =  259
#  y =  82
# x =  259
#  y =  82
# x =  300
#  y =  22
# x =  300
#  y =  22
# x =  259
#  y =  82
# x =  259
#  y =  82
# x =  300
#  y =  22
# x =  300
#  y =  22
# x =  248
#  y =  81
# x =  248
#  y =  81
# x =  300
#  y =  27
# x =  300
#  y =  27
# x =  300
#  y =  32
# x =  300
#  y =  32
# x =  299
#  y =  38
# x =  299
#  y =  38
# x =  299
#  y =  44
# x =  299
#  y =  44
# x =  299
#  y =  50
# x =  299
#  y =  50
# x =  299
#  y =  50
# x =  299
#  y =  50
# x =  298
#  y =  57
# x =  298
#  y =  57
# x =  292
#  y =  82
# x =  292
#  y =  82
# x =  298
#  y =  65
# x =  298
#  y =  65
# x =  299
#  y =  70
# x =  299
#  y =  70
# x =  304
#  y =  60
# x =  304
#  y =  60
# x =  308
#  y =  54
# x =  308
#  y =  54
# x =  308
#  y =  54
# x =  308
#  y =  54
# x =  312
#  y =  49
# x =  312
#  y =  49
# x =  314
#  y =  46
# x =  314
#  y =  46
# Processed video saved as 'shuttlecock_tracking.mp4'.
